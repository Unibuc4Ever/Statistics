# %% [markdown]
# # Sample R notebook
#
# _This is a sample notebook to check if it works ;)_

# %% [markdown]
# First we set `a` to be a linspace:
# $$a = \{ -10 * \Pi, \Pi + 1/10 + ... + 10 * \Pi \}$$

# %%
# Defining a
a <- seq(-10 * pi, 10 * pi, 0.1)

# %% [markdown]
# Now we plot a:

# %%
plot(a, sin(a))
# Out:
# plot without title
