# %% [markdown]
# # Sample R notebook
#
# _This is a sample notebook to check if it works ;)_

# %% [markdown]
# First we set `a` to be a linspace:
# $$a = \{ -10 * \Pi, \Pi + 1/10 + ... + 10 * \Pi \}$$

# %%
# Defining a
a <- seq(-5 * pi, 5 * pi, 0.05)

# %% [markdown]
# Now we plot a:

# %%
plot(a, sin(a))
# Out:
# plot without title
